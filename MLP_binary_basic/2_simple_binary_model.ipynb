# %% [markdown]
# 說明：和 1_simple_binary.ipynb 是同樣的功能，但建模的方式改寫了，使用 Keras (參考方法三)

# %% [markdown]
# ## 1. 起始資料集

# %%
import tensorflow as tf
import numpy as np


# 資料集
x1 = np.random.random((500,1))
x2 = np.random.random((500,1))+1
x_train = np.concatenate((x1, x2))

y1 = np.zeros((500,), dtype=int)
y2 = np.ones((500,), dtype=int)
y_train = np.concatenate((y1, y2))

# %% [markdown]
# ## 2. 不同的建立 model 的方式
# 其實都仍是 sequential 的方法

# %%
# 建立模型 (方法一)
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(10, activation=tf.nn.relu, input_dim=1),
  tf.keras.layers.Dense(10, activation=tf.nn.relu),
  tf.keras.layers.Dense(2, activation=tf.nn.softmax)
])

# %%
# 建立模型 (方法二)
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=10, activation=tf.nn.relu, input_dim=1))
model.add(tf.keras.layers.Dense(units=10, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(units=2, activation=tf.nn.softmax))

# %%
# 建立模型 (方法三)
# import keras
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(units=10, activation='relu', input_dim=1))
model.add(Dense(units=10, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %% [markdown]
# ## 3. 編譯、訓練、測試、預測

# %%
# 編譯
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# model.compile(optimizer='adam', loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])

# 訓練
model.fit(x_train, y_train, epochs=20, batch_size=128, verbose=0)

# 測試
x_test=np.array([[0.22], [0.31], [1.22], [1.33]])
y_test=np.array([0, 0, 1, 1])

loss, accuracy = model.evaluate(x_test, y_test, batch_size=128)
print('Loss:', loss)
print('Accuracy:', accuracy)

# 預測
predict = model.predict(x_test)
print('predict:', predict)
print('predict class:', np.argmax(predict[0]), np.argmax(predict[1]), np.argmax(predict[2]), np.argmax(predict[3]))
print('Y_test', y_test[:])
# Out:
# 1/1 [==============================] - 1s 731ms/step - loss: 0.6027 - accuracy: 1.0000
# Loss: 0.6026644706726074
# Accuracy: 1.0
# 1/1 [==============================] - 0s 437ms/step
# predict: [[0.5190932  0.48090672]
#  [0.51251155 0.48748842]
#  [0.4242759  0.57572407]
#  [0.41399515 0.58600485]]
# predict class: 0 0 1 1
# Y_test [0 0 1 1]
