# %% [markdown]
# ## CBow
# 先確認資料夾內有 ptsmalldata.zip 檔案

# %%
# 為了美觀，把Future Warning關閉
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# 把 zip 解壓縮到 data 資料夾
import zipfile
import os
if not os.path.exists("data"):
    f = zipfile.ZipFile("./pttsmalldata.zip")
    f.extractall("./data")
    f.close()

# %%
import glob  # 根據 Unix shell 使用的規則查找與指定模式匹配的所有路徑名稱
import json
import pandas as pd

# 拿取所有 *.json 檔案
fs = glob.glob("./data/pttsmalldata/*.json")

# 取用 內文 標題 和 型態(問卦...等等)
# 但實際上我們只使用 內文 做訓練而已
contents = []
titles = []
types = []
for fn in fs:
    with open(fn, "r", encoding="utf-8") as f:
        data = json.load(f)
        contents.append(data["post_content"])
        titles.append(data["post_title"])
        types.append(data["post_type"])

df = pd.DataFrame({
    "type":types,
    "title":titles,
    "content":contents
}, columns=["type", "title", "content"])
df
# Out:
#       type                 title  \
# 0       問卦   問一下 儀表板有一個潛水艇圖案一直發亮
# 1       問卦       外國大學賣學歷送學歷是常態嗎？
# 2       新聞   成反制罷韓箭靶 黃捷：能理解韓粉需宣洩
# 3       問卦  369兒童藝術工程是隸屬於什麼單位的卦?
# 4       新聞   韓國瑜是我的偶像 鳥來嬤轟綠：別只怪前
# ...    ...                   ...
# 19995   問卦        有明天是昨天的後天之八卦嗎？
# 19996   問卦                給羊喝飲料？
# 19997   問卦        看到替代役青年褲子會想認親嗎
# 19998   問卦       9200條煙是不是在偷渡概念？
# 19999   爆卦                  凱道熱爆
#
#                                                  content
# 0      \n暑假考到駕照，但是我去考駕照的時候，教練都沒教那些。\n\n搞得我現在很慌亂，儀表板有一...
# 1      \n那個啊\n聽說外國大學，\n只要捐錢蓋大樓，學校就會送你學歷\n聽說外國大學，\n只要是...
# 2      \n成反制罷韓箭靶 黃捷：能理解韓粉需宣洩\n\n（中央社記者王淑芬高雄1日電）台灣基進黨等...
# 3      \n369兒童藝術工程是隸屬於什麼單位的卦?\n還是 369兒童藝術工程是獨立單位?!\n為...
# 4      \n1.媒體來源: 中時電子報\n\n2.記者署名: 游定剛 、吳宥妤\n\n3.完整新聞標...
# ...                                                  ...
# 19995  \n有明天是昨天的後天之八卦嗎？\n\n朋友說\n\n明天是昨天的後天\n\n該怎麼回呢？\...
# 19996  \n\n大家好\n小妹 最近養了一頭羊\n羊大便一顆一顆的\n是不是因為羊都不喝水才會便秘啊...
# 19997  \n如果在外面\n\n看到有人穿熟悉的替代役青年的褲子\n\n就是深藍 淺藍 白的那件運動短...
# 19998  \n\n\n是這樣的\n\n最近吵得沸沸揚揚的事件\n\n個人認為重點不在於特權\n\n也不...
# 19999  \n我現在在凱道啦，\n熱爆，\n已經35度了！\n\n現場人山人海阿！\nhttps://...
#
# [20000 rows x 3 columns]

# %%
# 由於訓練會花超級久時間, 挑選前十篇進行訓練
df = df.head(100)

print(df)
# Out:
#    type                 title  \
# 0    問卦   問一下 儀表板有一個潛水艇圖案一直發亮
# 1    問卦       外國大學賣學歷送學歷是常態嗎？
# 2    新聞   成反制罷韓箭靶 黃捷：能理解韓粉需宣洩
# 3    問卦  369兒童藝術工程是隸屬於什麼單位的卦?
# 4    新聞   韓國瑜是我的偶像 鳥來嬤轟綠：別只怪前
# ..  ...                   ...
# 95   問卦        騎不快的單車　載滿你的友誼
# 96   問卦      肥肥放假在家除了烤秋勤還能幹嘛？
# 97   問卦      開法拉利跟蹤企鵝妹會怎樣????
# 98   問卦     世界上真的有人能不吃不喝不尿7天?
# 99   問卦          kodomo板還會復活嗎
#
#                                               content
# 0   \n暑假考到駕照，但是我去考駕照的時候，教練都沒教那些。\n\n搞得我現在很慌亂，儀表板有一...
# 1   \n那個啊\n聽說外國大學，\n只要捐錢蓋大樓，學校就會送你學歷\n聽說外國大學，\n只要是...
# 2   \n成反制罷韓箭靶 黃捷：能理解韓粉需宣洩\n\n（中央社記者王淑芬高雄1日電）台灣基進黨等...
# 3   \n369兒童藝術工程是隸屬於什麼單位的卦?\n還是 369兒童藝術工程是獨立單位?!\n為...
# 4   \n1.媒體來源: 中時電子報\n\n2.記者署名: 游定剛 、吳宥妤\n\n3.完整新聞標...
# ..                                                ...
# 95  \n\n\n\n騎不快的單車　載滿你的友誼　\n\n實在想問一句　停下等我行不行\n\n我知...
# 96  \nhi 大家今天過得好嗎\n\n\n本肥已經放假一年多了\n\n最近放的有點膩\n\n發現...
# 97  \n\n大家好，\n\n今天天氣不錯，\n\n如果小弟 我 開著我的買菜車，\n\nSF90...
# 98  \n印度奇人68年不吃不喝\n資料來源：大紀元新聞\n\n2003年11月27日\n\n\n...
# 99  \n安安大家好啊我是沒被掛掉的阿尼啦\n\n是這樣的 那個板還會再復出嗎？\n\n貼了那些邪...
#
# [100 rows x 3 columns]

# %% [markdown]
# ## 資料預處理 － 分詞
# - https://github.com/fxsjy/jieba
# - 找到更多的中文字典集

# %%
# 使用 jieba 進行分詞
import jieba
import os
from urllib.request import urlretrieve

# 使用大型字典
big_dict_path = "dict.txt.big"
if not os.path.exists(big_dict_path):
    print("下載大型字典")
    url = "https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big"
    urlretrieve(url, big_dict_path)
jieba.set_dictionary(big_dict_path)

# 需加入一些鄉民常用字彙
ptt_dict_path = "ptt_dic.txt"
if os.path.exists(ptt_dict_path):
    print("載入ptt專用詞典")
    jieba.load_userdict(ptt_dict_path)
# Out:
# Building prefix dict from /content/dict.txt.big ...
# DEBUG:jieba:Building prefix dict from /content/dict.txt.big ...
# Loading model from cache /tmp/jieba.u501edca284da514cb68b53a20324f4e3.cache
# DEBUG:jieba:Loading model from cache /tmp/jieba.u501edca284da514cb68b53a20324f4e3.cache
# 載入ptt專用詞典
# Loading model cost 1.256 seconds.
# DEBUG:jieba:Loading model cost 1.256 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.

# %%
import re
content = df.iloc[0]["content"]
print("Before:", content)

# 去掉網址 ptt的文章內容基本上都會換行 我們順便把最後的換行字元去掉
content = re.sub(r'https?:\/\/.*[\r\n]*', '', content)

# 使用 filter 去掉標點符號
punct = set(u''':!),.:;?]}¢'"、。〉》」』】〕〗〞→※︰︱︳﹐､﹒﹔﹕﹖﹗﹚﹜﹞！），．：；？｜｝︴︶︸︺︼︾﹀﹂﹄﹏､～￠々‖•·ˇˉ―--′’”([{£¥'"‵〈《「『【〔〖（［｛￡￥〝︵︷︹︻︽︿﹁﹃﹙﹛﹝（｛“‘-—_…~/ －＊➜■─★☆=@<>◉é''')
content = " ".join(filter(lambda x: x not in punct, jieba.cut(content)))

# 去掉換行符號
content = content.replace("\n", "").replace("\r", "")
print("After:", content)
# Out:
# Before:
# 暑假考到駕照，但是我去考駕照的時候，教練都沒教那些。
#
# 搞得我現在很慌亂，儀表板有一個潛水艇圖案的燈一直亮
#
# 是什麼意思？
#
# --
# 真假
# 我納智傑耶
# 推 wayne80619: 這個？https://i.imgur.com/T1ZAedp.j     39.8.33.166 08/28 00:32
# → Anvec: 那個燈是告訴你小心潛艇 不要撞到它        124.155.174.232 08/28 00:34
# 橘色的
# ※ 編輯: poeta (125.231.12.41 臺灣), 08/28/2019 00:37:22
#
# After:  暑假 考 到 駕照 但是 我 去 考駕照 的 時候 教練 都 沒教 那些   搞 得 我 現在 很 慌亂 儀表板 有 一個 潛水艇 圖案 的 燈 一直 亮   是 什麼 意思   --  真假  我納智傑 耶  推 wayne80619 這個 Anvec 那個 燈是 告訴 你 小心 潛艇 不要 撞 到 它 124.155 174.232 08 28 00 34  橘色 的  編輯 poeta 125.231 12.41 臺灣 08 28 2019 00 37 22

# %%
# 對表格的每一筆都做出轉換
def process(content):
    content = re.sub(r'https?:\/\/.*[\r\n]*', '', content)
    content = "".join(filter(lambda x: x not in punct, content))
    content = (" ".join(jieba.cut(content))
                  .replace("\n", "")
                  .replace("\r", ""))
    return content

content_cut = df["content"].apply(process)
content_cut
# Out:
# 0      暑假 考 到 駕照 但是 我 去 考駕照 的 時候 教練 都 沒教 那些   搞 得 我 ...
# 1      那個 啊  聽說 外國 大學  只要 捐錢 蓋 大樓 學校 就 會 送 你 學歷  聽說 ...
# 2      成 反制 罷韓 箭靶 黃 捷能 理解 韓粉 需宣洩   中央社 記者 王淑芬 高雄 1 日...
# 3      369 兒童 藝術 工程 是 隸屬於 什麼 單位 的 卦  還是 369 兒童 藝術 工程...
# 4      1 媒體 來源 中時 電子報   2 記者 署名 游定剛 吳宥 妤   3 完整 新聞標題...
#                             ...
# 95        騎 不快 的 單車 　 載滿 你 的 友誼 　   實在 想問 一句 　 停下 等 ...
# 96     hi 大家 今天 過得 好 嗎    本肥 已經 放假 一年 多 了   最近 放 的 有...
# 97      大家 好   今天天氣 不錯   如果 小弟 我 開著 我 的 買菜 車   SF90S...
# 98     印度 奇人 68 年 不吃不喝  資料 來源 大 紀元 新聞   2003 年 11 月 ...
# 99     安安 大家 好 啊 我 是 沒 被 掛掉 的 阿尼 啦   是 這樣 的 那個 板 還會 ...
# Name: content, Length: 100, dtype: object

# %% [markdown]
# ## 建立模型

# %%
import numpy as np
np.random.seed(13)
import keras.backend as K
from keras.models import Sequential
from keras.layers import Dense, Embedding, Lambda
from tensorflow.python.keras.utils import np_utils
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer # 找出有多少種詞，並給出代表數字樣
import gensim

# %%
# 語料庫
# 太少字的句子我們去掉, 因為這樣無法移動
print(content_cut)

corpus = []
# for c in content_cut:
#   corpus = corpus + [s for s in c.split("\n")
#                 if s.count(" ")>=2]
corpus = [sentence for sentence in content_cut if sentence.count(' ') >= 2]
print(corpus)
# Out:
# 0      暑假 考 到 駕照 但是 我 去 考駕照 的 時候 教練 都 沒教 那些   搞 得 我 ...
# 1      那個 啊  聽說 外國 大學  只要 捐錢 蓋 大樓 學校 就 會 送 你 學歷  聽說 ...
# 2      成 反制 罷韓 箭靶 黃 捷能 理解 韓粉 需宣洩   中央社 記者 王淑芬 高雄 1 日...
# 3      369 兒童 藝術 工程 是 隸屬於 什麼 單位 的 卦  還是 369 兒童 藝術 工程...
# 4      1 媒體 來源 中時 電子報   2 記者 署名 游定剛 吳宥 妤   3 完整 新聞標題...
#                             ...
# 95        騎 不快 的 單車 　 載滿 你 的 友誼 　   實在 想問 一句 　 停下 等 ...
# 96     hi 大家 今天 過得 好 嗎    本肥 已經 放假 一年 多 了   最近 放 的 有...
# 97      大家 好   今天天氣 不錯   如果 小弟 我 開著 我 的 買菜 車   SF90S...
# 98     印度 奇人 68 年 不吃不喝  資料 來源 大 紀元 新聞   2003 年 11 月 ...
# 99     安安 大家 好 啊 我 是 沒 被 掛掉 的 阿尼 啦   是 這樣 的 那個 板 還會 ...
# Name: content, Length: 100, dtype: object
# [' 暑假 考 到 駕照 但是 我 去 考駕照 的 時候 教練 都 沒教 那些   搞 得 我 現在 很 慌亂 儀表板 有 一個 潛水艇 圖案 的 燈 一直 亮   是 什麼 意思    真假  我納智傑 耶  推 wayne80619 這個 Anvec 那個 燈是 告訴 你 小心 潛艇 不要 撞 到 它 12415517423208280034  橘色 的  編輯 poeta1252311241 臺灣 08282019003722 ', ' 那個 啊  聽說 外國 大學  只要 捐錢 蓋 大樓 學校 就 會 送 你 學歷  聽說 外國 大學  只要 是 名人 不管 有沒有 畢業 都 會 想 辦法 蹭 上去 蹭 知名度 就 會 送 你 學歷   有沒有 卦   ', ' 成 反制 罷韓 箭靶 黃 捷能 理解 韓粉 需宣洩   中央社 記者 王淑芬 高雄 1 日電 台灣 基進 黨 等 社團 展開 罷韓 行動 為 了 反制 這股 風  潮 罷免 高雄市 議員 黃 捷粉 專也 發起 罷免 時代 力量 市議員 黃 捷 做 為 反 制黃 捷 今天 說  韓粉 需要 宣洩 出口 能 理解 成為 箭靶   包括 基進 黨 Wecare 高雄 等 社團 發起 罷免 高雄 市長 韓國 瑜 行動 熱烈 展開 韓的 支持者 難以  接受 為 了 反制 此 風潮 網路 社群 成立 罷免 高雄市 議員 黃 捷粉 專要 罷免 黃 捷 等 人   雖 是 政壇 新人 黃 捷 在 監督 韓國 瑜 及 市府 團隊 不 手軟 砲 火 猛烈 在 市議會 定期 大會 質詢  自經 區因 不滿 韓的 答覆 氣到 翻白眼 黃 捷 因而 被 網友 封為 新 鄉民 女神 網路 知名  度 飆升   面對 網路 社群 粉 專發 起 罷免 黃 捷 今天 在 服務處 受訪 表示 尊重 行使 公民權利 她 說  在 議會 盡 監督 責任 相信 市民 眼
順序 任意 刪除 者 會 被刪 文   1 媒體 來源  自由   2 記者 署名  記者 邱俊福 黃建華 ／ 綜合 報導   3 完整 新聞標題  角頭 客串 電影 小 角頭 林德源 超護 同門 連千毅   4 完整 新聞 內文  遭 檢肅 到案 的 林德源 綽號 源哥 自稱 統促 黨 自如 黨部 副 主委 他 曾 參與 知名 電影  角頭 的 演出 飾演 一名 小 角頭 警方 調查 他 與 直播 主之亂 主角 連千毅 系出 同門 都  有 竹 聯幫 天龍 堂 背景 2 人 早就 相識 連千毅 南下 高雄 插旗 並在 直播 圈 竄 紅後林 嫌 儼  然成 了 連的 護衛 隊長     上 月 17 日連千毅 跟 ...

# %%
# 將每一個詞轉成數字
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus) # 找出有多少種詞
print(tokenizer.word_index)

corpus_seq = tokenizer.texts_to_sequences(corpus) # 執行轉換
print(corpus_seq)

# 統計訓練資料有多少個詞
nb_samples = sum(len(s) for s in corpus_seq)
print(nb_samples)

# 統計我們有多少種詞
V = len(tokenizer.word_index) + 1 # 抓上下文，有時前面會沒有

# 降維成100 (依語料數量決定)
dim = 100

# 上文取2 下文取2
window_size = 2
# Out:
# {'的': 1, '是': 2, '在': 3, '了': 4, '我': 5, '有': 6, '都': 7, '也': 8, '就': 9, '他': 10, '不': 11, '人': 12, '台灣': 13, '要': 14, '被': 15, '為': 16, '嗎': 17, '說': 18, '完整': 19, '很': 20, '你': 21, '會': 22, '與': 23, '到': 24, '日': 25, '後': 26, '什麼': 27, '表示': 28, '新聞': 29, '對': 30, '現在': 31, '但': 32, '1': 33, '或': 34, '2': 35, '3': 36, '編輯': 37, '記者': 38, '好': 39, '5': 40, '\u3000': 41, '█': 42, '她': 43, '八卦': 44, '海峽': 45, '韓國': 46, '時': 47, '4': 48, '月': 49, '看': 50, '臺灣': 51, '做': 52, '年': 53, '如果': 54, '中國': 55, '日本': 56, '艦': 57, '媒體': 58, '中': 59, '沒': 60, '多': 61, '跟': 62, '沒有': 63, '請': 64, '上': 65, '而': 66, '個': 67, '美國': 68, '啊': 69, '有沒有': 70, '和': 71, '還是': 72, '歲': 73, '6': 74, '發現': 75, '台': 76, '短': 77, '去': 78, '這樣': 79, '板': 80, '大': 81, '7': 82, '就是': 83, '等': 84, '可以': 85, '大家': 86, '10': 87, '我們': 88, '又': 89, '卻': 90, '覺得': 91, '這': 92, '政治': 93, '讓': 94, '郭芷嫣': 95, '解放軍': 96, '一個': 97, '應該': 98, '以': 99, '來源': 100, '之': 101, '知道': 102, '不會': 103, '並': 104, '不要': 105, '更': 106, '報導': 107, '億元': 108, '對方': 109, '投資': 110, '才': 111, '有人': 112, '那': 113, '再': 114, '但是': 115, '能': 116, '市長': 117, '於': 118, '署名': 119, '連結': 120, '網址': 121, '台北': 122, '退稅': 123, '結果': 124, '已經': 125, '時間': 126, '想': 127, '今天': 128, '瑜': 129, '／': 130, '內文': 131, '注意': 132, '向': 133, '因': 134, '不能': 135, '因為': 136, '睡眠': 137, '用': 138, '身心': 139, '這個': 140, '卦': 141, '這種': 142, '自己': 143, '新聞標
46, 129, 281, 3, 1212, 2138, 18, 579, 30, 2139, 172, 2140, 1, 580, 199, 88, 171, 2141, 1, 2142, 170, 274, 128, 118, 813, 174, 381, 200, 46, 129, 89, 581, 2143, 175, 71, 2144, 2145, 1, 282, 814, 43, 2146, 142, 282, 2147, 1, 12, 173, 6, 2148, 577, 376, 461], [1213, 815, 1214, 1215, 2, 2149, 27, 1216, 1, 141, 72, 1213, 815, 1214, 1215, 2, 2150, 1216, 16, 4, 1217, 1, 2151, 2152, 9, 156, 143, 788, 1, 2153, 6, 2154, 17, 1218, 1219, 2155, 2156, 2157, 1219, 2158, 2159, 2160], [33, 58, 100, 283, 582, 35, 38, 119, 2161, 2162, 2163, 36, 19, 144, 2164, 130, 46, 129, 2, 5, 1, 2165, 816, 583, 2166, 239, 2167, 817, 48, 19, 29, 131, 806, 1220, 279, 1221, 2168, 2169, 2170, 1197, 2171, 818, 1222, 1223, 816, 583, 1224, 1225, 2172, 8, 2173, 13, 584, 23, 145, 2174, 198, 283, 582, 819, 2175, 1226, 46, 129, 1227, 6, 2176, 90, 8, 820, 2177, 470, 225, 105, 2178, 817, 2179, 2180, 2181, 2182, 2183, 2184, 2185, 2186, 2187, 1228, 2188, 73, 1, 1222, 1223, 816, 583, 1224, 240, 585, 821, 146, 2189, 53, 2190, 2191, 382, 156, 2192, 2193, 4, 1229, 1230, 2194, 47, 822, 90, 383, 823, 2195, 2196, 2197, 2198, 1231, 2199, 28, 2200, 11, 1232, 21, 586, 372, 372, 9, 1233, 21, 21, 1233, 372, 372, 9, 586, 21, 5, 11, 571, 2201, 2202, 5, 2203, 4, 5, 2, 1234, 241, 2204, 76, 59, 2205, 2206, 2207, 86, 824, 384, 31, 2208, 20, 39, 1235, 4, 2209, 2210, 53, 4, 325, 38, 284, 2211, 825, 1236, 587, 1, 471, 2212, 2213, 1236, 826, 1, 384, 2, 5, 587, 1, 2214, 5, 2215, 6, 27, 18, 27, 2216, 201, 2217, 3, 22, 2218, 2219, 2220, 285, 18, 201, 2221, 1235, 4, 88, 14, 2222, 827, 13, 12, 16, 2223, 157, 583, 588, 25, 198, 283, 582, 819, 47, 28, 13, 2224, 89, 11, 1237, 1, 242, 8, 2, 88, 2225, 2226, 1, 39, 242, 2227, 2228, 2229, 24, 589, 828, 7, 590, 385, 2230, 1225, 101, 2231, 591, 5, 20, 2232, 13, 2233, 2234, 66, 325, 2235, 26, 1238, 2236, 2237, 2238, 117, 2239, 386, 829, 58, 2240, 830, 38, 284, 806, 382, 2241, 592, 1221, 158, 2242, 1239, 147, 2243, 2244, 820, 2245, 466, 2246, 470, 225, 385, 88, 52, 47 ...
# 15041

# %%
# 產生訓練資料
def generate_data(corpus, window_size, V):
    # 拿最多 上文(2) + 下文(2)
    maxlen = window_size * 2
    # 拿出每一句
    for words in corpus:
        L = len(words)
        # 拿出每一個單字
        for index, word in enumerate(words):
            # contexts: [上文, 下文]
            # labels: 目標
            contexts = []
            labels  = []
            # 上文的最前面座號
            s = index - window_size
            # 下文的最後面座號
            e = index + window_size
            # range記得要多加1
            contexts.append([words[i] for i in range(s, e + 1)
                            if 0 <= i < L and i != index])
            labels.append(word)
            # 少於四個的前面補上0
            x = sequence.pad_sequences(contexts, maxlen=maxlen)
            # 答案做出one-hot encoding
            y = np_utils.to_categorical(labels, V)
            yield (x, y) # 配合 for..in，每次回傳

# %%
# test
g = generate_data(corpus_seq, window_size, V)
g.__next__()
# Out:
# (array([[   0,    0, 1175,   24]], dtype=int32),
#  array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32))

# %%
cbow = Sequential()
# 使用嵌入層來得到轉化過的語意
cbow.add(Embedding(input_dim=V, output_dim=dim, input_length=window_size*2))
# 針對4個詞的100語意做平均
cbow.add(Lambda(lambda x: K.mean(x, axis=1), output_shape=(dim,)))
# 輸出判斷
cbow.add(Dense(V, activation='softmax'))
cbow.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 4, 100)            512700
#
#  lambda_1 (Lambda)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 5127)              517827
#
# =================================================================
# Total params: 1030527 (3.93 MB)
# Trainable params: 1030527 (3.93 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cbow.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
# 訓練十個epochs
for i in range(10):
    loss = 0.
    for x, y in generate_data(corpus_seq, window_size, V):
        loss += cbow.train_on_batch(x, y)
    print("-" * 15, "Iteration", i, "-" * 15)
    print(loss)
# Out:
# --------------- Iteration 0 ---------------
# 131482.70037549734
# --------------- Iteration 1 ---------------
# 117236.6280207783
# --------------- Iteration 2 ---------------
# 107392.88152040466
# --------------- Iteration 3 ---------------
# 96211.04470475011
# --------------- Iteration 4 ---------------
# 85616.00693035507
# --------------- Iteration 5 ---------------
# 76069.74431834547
# --------------- Iteration 6 ---------------
# 67681.58574392916
# --------------- Iteration 7 ---------------
# 60403.088201705024
# --------------- Iteration 8 ---------------
# 54155.31882168967
# --------------- Iteration 9 ---------------
# 48806.8370019468

# %% [markdown]
# ## 儲存和使用模型
# - Gensim 函式庫

# %%
# 準備寫入我們的向量
f = open('vectors.txt' ,'w')
f.write('{} {}\n'.format(V-1, dim))
# Out:
# 9

# %%
vectors = cbow.get_weights()[0] # 嵌入層的值
for word, i in tokenizer.word_index.items():
    # 存擋的時候必須是 2 3 1 這樣空白鍵在中間
    # 但是在用join時裡面必須是字串, 所以先用map轉換成字串
    str_vec = ' '.join(map(str, list(vectors[i, :])))
    f.write('{} {}\n'.format(word, str_vec))
f.close()

# %%
w2v = gensim.models.KeyedVectors.load_word2vec_format('./vectors.txt', binary=False)

# %%
w2v.most_similar("記者")
# Out:
# [('即時新聞', 0.4673621654510498),
#  ('聯合報', 0.46424737572669983),
#  ('吳宥', 0.44850799441337585),
#  ('／', 0.4339748024940491),
#  ('綜合', 0.4139289855957031),
#  ('鄭文正', 0.40802496671676636),
#  ('中央社', 0.40728282928466797),
#  ('針對', 0.3761875033378601),
#  ('署名', 0.3735869824886322),
#  ('抱歉', 0.37153565883636475)]

# %%
w2v.most_similar("台北")
# Out:
# [('綜合', 0.5593392252922058),
#  ('莒光', 0.4918971061706543),
#  ('花蓮', 0.47878366708755493),
#  ('日將', 0.44577425718307495),
#  ('地檢署', 0.4042806625366211),
#  ('今問', 0.3982866108417511),
#  ('蘇亨俊前', 0.3793930411338806),
#  ('／', 0.3777710795402527),
#  ('年', 0.37493956089019775),
#  ('記者', 0.3702332675457001)]
