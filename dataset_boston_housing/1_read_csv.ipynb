# %% [markdown]
# # Dataset: Boston Housing

# %% [markdown]
# ## 起始準備 （Colab 連接雲端硬碟)

# %%
# 連接雲端硬碟，起始準備

from google.colab import drive
drive.mount('/content/drive')

# 移到資料夾
# %cd /content/drive/MyDrive/class_AI/dataset_boston_housing/
# !pwd
# !ls

# %% [markdown]
# ## 取得及認識資料

# %%
# 載入資料集
import pandas as pd

df = pd.read_csv('boston.csv')
print(df)

# %%
print(df.shape)

# %%
print(df.head())

# %%
print(df.describe())

# %%
# 顯示所有的欄位
pd.set_option('display.max_columns', None)
# pd.set_option('max_columns', None)
# pd.set_option('max_columns', 3)
# pd.reset_option('max_columns')  # reset to default
df.head()

# %% [markdown]
# ## 圖表繪製分析資料 (略)

# %%
import numpy as np
import matplotlib.pyplot as plt
