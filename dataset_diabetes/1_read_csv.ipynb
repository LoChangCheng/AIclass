# %% [markdown]
# # Dataset: Diabetes

# %% [markdown]
# **檔案如讀取錯誤，則直接從網路上抓資料來使用**

# %% [markdown]
# ## 起始準備 （Colab 連接雲端硬碟)

# %%
# 連接雲端硬碟，起始準備

from google.colab import drive
drive.mount('/content/drive')

# 移到資料夾
# %cd /content/drive/MyDrive/class_AI/dataset_diabetes/
# !pwd
# !ls

# %%
#上傳檔案方法複習
from google.colab import files
uploaded = files.upload()

# %%
# 讀取網路資料
# !wget 'https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv'

# %%
# !ls

# %% [markdown]
# ## 取得及認識資料

# %%
# 載入資料集
import pandas as pd

df = pd.read_csv('diabetes.csv')
print(df)

# %%
print(df.shape)

# %%
print(df.head())

# %%
print(df.describe())

# %%
# 顯示所有的欄位
pd.set_option('display.max_columns', None)
# pd.set_option('max_columns', None)
# pd.set_option('max_columns', 3)
# pd.reset_option('max_columns')  # reset to default
df.head()

# %% [markdown]
# ## 資料檢查

# %%
# 找到 Outcome 不重覆項目的名稱
# 方法一
df['Outcome'].unique()

# %%
# 找到 taget 不重覆項目的名稱
# 方法二
df.drop_duplicates(['Outcome'])
